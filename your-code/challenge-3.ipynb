# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# Import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# Enter your code here
orders_df = pd.read_csv("/Users/diegoperezo97/Documents/IronHack – Data Analytics Bootcamp/Module 2/Week 4/Day 1/lab-subsetting-and-descriptive-stats/your-code/Orders.csv")
orders_df.shape
# Out:
# (397924, 14)

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
orders_sub_df = orders_df[['CustomerID', 'amount_spent']].groupby(by='CustomerID', as_index=False).sum()
orders_sub_df
# Out:
#       CustomerID  amount_spent
# 0          12346      77183.60
# 1          12347       4310.00
# 2          12348       1797.24
# 3          12349       1757.55
# 4          12350        334.40
# ...          ...           ...
# 4334       18280        180.60
# 4335       18281         80.82
# 4336       18282        178.05
# 4337       18283       2094.88
# 4338       18287       1837.28
#
# [4339 rows x 2 columns]

# %%
customer_id = orders_sub_df['CustomerID'].values.tolist()
amount_spent = orders_sub_df['amount_spent'].values.tolist()

Q1 = np.percentile(amount_spent, 25, interpolation = 'midpoint')
Q3 = np.percentile(amount_spent, 75, interpolation = 'midpoint')
IQR = Q3 - Q1
maximum = Q3 + 1.5*IQR

vip_customers = []
preferred_customers = []

for cust_id, amount in zip(customer_id, amount_spent):
    if amount >= Q3 and amount < maximum:
        preferred_customers.append(cust_id)
    elif amount > maximum:
        vip_customers.append(cust_id)

# %%
preferred_customers = pd.DataFrame(preferred_customers, columns=['CustomerID'])
preferred_customers = preferred_customers.merge(right=orders_df, how='inner', left_on='CustomerID', right_on='CustomerID')
preferred_customers
# Out:
#        CustomerID  Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           12348       34083     539318     84992  2010     12    4    19
# 1           12348       34084     539318     22951  2010     12    4    19
# 2           12348       34085     539318     84991  2010     12    4    19
# 3           12348       34086     539318     84991  2010     12    4    19
# 4           12348       34087     539318     21213  2010     12    4    19
# ...           ...         ...        ...       ...   ...    ...  ...   ...
# 98946       18287      392752     570715     22419  2011     10    3    10
# 98947       18287      392753     570715     22866  2011     10    3    10
# 98948       18287      423939     573167     23264  2011     10    5     9
# 98949       18287      423940     573167     21824  2011     10    5     9
# 98950       18287      423941     573167     21014  2011     10    5     9
#
# ...

# %%
vip_customers = pd.DataFrame(vip_customers, columns=['CustomerID'])
vip_customers = vip_customers.merge(right=orders_df, how='inner', left_on='CustomerID', right_on='CustomerID')
vip_customers
# Out:
#         CustomerID  Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0            12346       61619     541431     23166  2011      1    2    10
# 1            12347       14938     537626     85116  2010     12    2    14
# 2            12347       14939     537626     22375  2010     12    2    14
# 3            12347       14940     537626     71477  2010     12    2    14
# 4            12347       14941     537626     22492  2010     12    2    14
# ...            ...         ...        ...       ...   ...    ...  ...   ...
# 157309       18251      339460     566595     22096  2011      9    2    15
# 157310       18251      339461     566595     22909  2011      9    2    15
# 157311       18251      339462     566595     22950  2011      9    2    15
# 157312       18251      339463     566595     22952  2011      9    2    15
# 157313       18251      339464     566595     22138  2011      9    2    15
#
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# Provide your solution for Q2 below:

# %%
# Your code here

countries_q2 = vip_customers[['Country', 'CustomerID']].groupby(by='Country', as_index=False).count().sort_values(by='CustomerID', ascending=False).head(1)
countries_q2
# Out:
#            Country  CustomerID
# 21  United Kingdom      130199

# %%
vip_and_preferred_customers = pd.concat([vip_customers, preferred_customers])
countries_q3 = vip_and_preferred_customers[['Country', 'CustomerID']].groupby(by='Country', as_index=False).count().sort_values(by='CustomerID', ascending=False).head(1)
countries_q3
# Out:
#            Country  CustomerID
# 26  United Kingdom      221635
